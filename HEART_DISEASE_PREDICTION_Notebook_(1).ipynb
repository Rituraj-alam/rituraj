# %% [markdown]
# <a href="https://colab.research.google.com/github/Rituraj-alam/rituraj/blob/main/HEART_DISEASE_PREDICTION_Notebook_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd,numpy as np, seaborn as sn, matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-fd8ed795-62b7-4ba1-82ff-4dbefb75eb53" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd8ed795-62b7-4ba1-82ff-4dbefb75eb53">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
myfiles="heart.csv"

# %%
data=pd.read_csv(myfiles)

# %%
data.shape
# Out:
# (1025, 14)

# %%
data['target'].value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# # DATA DESCRIPTION

# %% [markdown]
# ```
# It's a clean, easy to understand set of data. However, the meaning of some of the column headers are not obvious. Here's what they mean,
# •	age: The person's age in years
# •	sex: The person's sex (1 = male, 0 = female)
# •	cp: The chest pain experienced (Value 1: typical angina, Value 2: atypical angina, Value 3: non-anginal pain, Value 4: asymptomatic)
# •	trestbps: The person's resting blood pressure (mm Hg on admission to the hospital)
# •	chol: The person's cholesterol measurement in mg/dl
# •	fbs: The person's fasting blood sugar (> 120 mg/dl, 1 = true; 0 = false)
# •	restecg: Resting electrocardiographic measurement (0 = normal, 1 = having ST-T wave abnormality, 2 = showing probable or definite left ventricular hypertrophy by Estes' criteria)
# •	thalach: The person's maximum heart rate achieved
# •	exang: Exercise induced angina (1 = yes; 0 = no)
# •	oldpeak: ST depression induced by exercise relative to rest ('ST' relates to positions on the ECG plot. See more here)
# •	slope: the slope of the peak exercise ST segment (Value 1: upsloping, Value 2: flat, Value 3: downsloping)
# •	ca: The number of major vessels (0-3)
# •	thal: A blood disorder called thalassemia (3 = normal; 6 = fixed defect; 7 = reversable defect)
# •	target: Heart disease (0 = no, 1 = yes)
# ```

# %% [markdown]
# # DATA VISUALIZATION

# %%
plt.figure(figsize=(12,10))
sn.heatmap(data.corr(),annot=True,cmap="magma",fmt='.2f')
# Out:
# <Axes: >

# %%
sn.set_style('darkgrid')
sn.set_palette('Set2')

# %%
df = data.copy()

# %%
def chng(sex):
    if sex == 0:
        return 'female'
    else:
        return 'male'
df['sex'] = df['sex'].apply(chng)

# %%
def chng2(prob):
    if prob == 0:
        return 'Heart Disease'
    else:
        return 'No Heart Disease'
df['target'] = df['target'].apply(chng2)

# %%
sn.countplot(data= df, x='sex',hue='target')
plt.title('Gender v/s target\n')
# Out:
# Text(0.5, 1.0, 'Gender v/s target\n')

# %%
sn.countplot(data= df, x='cp',hue='target')
plt.title('Chest Pain Type v/s target\n')
# Out:
# Text(0.5, 1.0, 'Chest Pain Type v/s target\n')

# %%
sn.countplot(data= df, x='sex',hue='thal')
plt.title('Gender v/s Thalassemia\n')
print('Thalassemia  is an inherited blood disorder that causes your body to have less hemoglobin than normal. Hemoglobin enables red blood cells to carry oxygen')
# Out:
# Thalassemia  is an inherited blood disorder that causes your body to have less hemoglobin than normal. Hemoglobin enables red blood cells to carry oxygen

# %%
sn.countplot(data= df, x='slope',hue='target')
plt.title('Slope v/s Target\n')
# Out:
# Text(0.5, 1.0, 'Slope v/s Target\n')

# %%
sn.countplot(data= df, x='exang',hue='thal')
plt.title('exang v/s Thalassemia\n')
# Out:
# Text(0.5, 1.0, 'exang v/s Thalassemia\n')

# %%
plt.figure(figsize=(14,8))
sn.violinplot(data=df,x='ca',y='age',hue='target')
# Out:
# <Axes: xlabel='ca', ylabel='age'>

# %%
plt.figure(figsize=(14,8))
sn.boxplot(data=df,x='ca',y='age',hue='target')
# Out:
# <Axes: xlabel='ca', ylabel='age'>

# %%
sn.boxplot(data=df,x='cp',y='thalach',hue='target')
# Out:
# <Axes: xlabel='cp', ylabel='thalach'>

# %%
sn.violinplot(data=df,x='target',y='thalach')
# Out:
# <Axes: xlabel='target', ylabel='thalach'>

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sn.lmplot(x="age",y="chol",data=data)

# %%
X=data.drop('target',axis=1)
y=data['target']

# %%
knn=KNeighborsClassifier()

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=26)

# %%
k_values = range(1, 21)
accuracies = []

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    accuracies.append(accuracy)

# %%
plt.plot(k_values, accuracies)
plt.xlabel('k')
plt.ylabel('Accuracy')
plt.title('KNN: Accuracy vs. k')
plt.show()

# %%
knn=KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 91.71%

# %%
from sklearn.metrics import classification_report , confusion_matrix , f1_score,precision_score,recall_score

# %%
fscore=f1_score(y_test ,y_pred)

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
ps=precision_score(y_test,y_pred)

# %%
rs=recall_score(y_test,y_pred)

# %%
fscore
# Out:
# 0.9128205128205128

# %%
cm
# Out:
# array([[99,  5],
#        [12, 89]])

# %%
ps
# Out:
# 0.7368421052631579

# %%
rs
# Out:
# 0.8811881188118812

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
X = data.iloc[:,0:13] # Features
y = data.iloc[:,13] # Target variable
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9902597402597403
